# %% [markdown]
# <a href="https://colab.research.google.com/github/Shreyas3108/Upgrad_DS/blob/master/20190611_Pandas_Basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
#california_housing_dataframe = pd.read_csv("https://download.mlcc.google.com/mledu-datasets/california_housing_train.csv", sep=",")
#california_housing_dataframe.describe()

# %%
ser = pd.Series([8,3,1,9,5])

# %%
ser
# Out:
# 0    8
# 1    3
# 2    1
# 3    9
# 4    5
# dtype: int64

# %%
ser[:2]
# Out:
# 0    8
# 1    3
# dtype: int64

# %%
l = [8,3,1,9,5]

# %%
l[0]
# Out:
# 8

# %%
l[:2]
# Out:
# [8, 3]

# %%
ser1 = pd.Series(['Akshay' , 2 , 'Ayan','Akshay'])

# %%
ser1.describe()
# Out:
# count          4
# unique         3
# top       Akshay
# freq           2
# dtype: object

# %%
type(ser1[0])
# Out:
# str

# %%
d1 = {'City':['Chennai','Delhi','London','Melbourne','Chennai','Delhi'] , 'Temperature':[40 , 38 , 11 , 15 , 32 , 29]}

# %%
df1 = pd.DataFrame(d1)

# %%
df1.City
# Out:
# 0      Chennai
# 1        Delhi
# 2       London
# 3    Melbourne
# 4      Chennai
# 5        Delhi
# Name: City, dtype: object

# %%
df1['index'] = [1,2,3,4,5,np.nan]

# %%
df1.dtypes
# Out:
# City            object
# Temperature      int64
# index          float64
# dtype: object

# %%
df = pd.read_csv("https://raw.githubusercontent.com/Shreyas3108/Weather/master/weather.csv")

# %%
df.shape
# Out:
# (366, 24)

# %%
df.head()
# Out:
#         Date  Location  MinTemp  ...  RainToday  RISK_MM  RainTomorrow
# 0  11/1/2007  Canberra      8.0  ...         No      3.6           Yes
# 1  11/2/2007  Canberra     14.0  ...        Yes      3.6           Yes
# 2  11/3/2007  Canberra     13.7  ...        Yes     39.8           Yes
# 3  11/4/2007  Canberra     13.3  ...        Yes      2.8           Yes
# 4  11/5/2007  Canberra      7.6  ...        Yes      0.0            No
#
# [5 rows x 24 columns]

# %%
df.describe(percentiles=[0.1 , 0.3 , 0.5 , 0.7,0.8,0.9])
# Out:
#           MinTemp     MaxTemp    Rainfall  ...     Temp9am     Temp3pm     RISK_MM
# count  366.000000  366.000000  366.000000  ...  366.000000  366.000000  366.000000
# mean     7.265574   20.550273    1.428415  ...   12.358470   19.230874    1.428415
# std      6.025800    6.690516    4.225800  ...    5.630832    6.640346    4.225800
# min     -5.300000    7.600000    0.000000  ...    0.100000    5.100000    0.000000
# 10%     -0.900000   12.150000    0.000000  ...    5.250000   11.100000    0.000000
# 30%      3.200000   16.150000    0.000000  ...    8.400000   14.950000    0.000000
# 50%      7.450000   19.650000    0.000000  ...   12.550000   18.550000    0.000000
# 70%     11.700000   24.250000    0.000000  ...   16.300000   22.550000    0.000000
# 80%     13.200000   26.900000    0.800000  ...   17.500000   25.200000    0.800000
# 90%     15.300000   29.950000    4.300000  ...   19.700000   28.600000    4.300000
# ...

# %%
df.describe(include = ['O','int','float'])
# Out:
#               Date  Location     MinTemp  ...  RainToday     RISK_MM  RainTomorrow
# count          366       366  366.000000  ...        366  366.000000           366
# unique         366         1         NaN  ...          2         NaN             2
# top     10/28/2008  Canberra         NaN  ...         No         NaN            No
# freq             1       366         NaN  ...        300         NaN           300
# mean           NaN       NaN    7.265574  ...        NaN    1.428415           NaN
# std            NaN       NaN    6.025800  ...        NaN    4.225800           NaN
# min            NaN       NaN   -5.300000  ...        NaN    0.000000           NaN
# 25%            NaN       NaN    2.300000  ...        NaN    0.000000           NaN
# 50%            NaN       NaN    7.450000  ...        NaN    0.000000           NaN
# 75%            NaN       NaN   12.500000  ...        NaN    0.200000           NaN
# ...

# %%
df['Temp_diff'] = df['Temp3pm'] - df['Temp9am']

# %%
s1 = df['Temp_diff'].copy()

# %%
df.head()
# Out:
#         Date  Location  MinTemp  ...  RISK_MM  RainTomorrow  Temp_diff
# 0  11/1/2007  Canberra      8.0  ...      3.6           Yes        9.2
# 1  11/2/2007  Canberra     14.0  ...      3.6           Yes        8.2
# 2  11/3/2007  Canberra     13.7  ...     39.8           Yes        4.8
# 3  11/4/2007  Canberra     13.3  ...      2.8           Yes        0.6
# 4  11/5/2007  Canberra      7.6  ...      0.0            No        4.3
#
# [5 rows x 25 columns]

# %%
df[['Location','MinTemp','MaxTemp']]
# Out:
#      Location  MinTemp  MaxTemp
# 0    Canberra      8.0     24.3
# 1    Canberra     14.0     26.9
# 2    Canberra     13.7     23.4
# 3    Canberra     13.3     15.5
# 4    Canberra      7.6     16.1
# 5    Canberra      6.2     16.9
# 6    Canberra      6.1     18.2
# 7    Canberra      8.3     17.0
# 8    Canberra      8.8     19.5
# 9    Canberra      8.4     22.8
# 10   Canberra      9.1     25.2
# 11   Canberra      8.5     27.3
# 12   Canberra     10.1     27.9
# 13   Canberra     12.1     30.9
# 14   Canberra     10.1     31.2
# 15   Canberra     12.4     32.1
# 16   Canberra     13.8     31.2
# 17   Canberra     11.7     30.0
# 18   Canberra     12.4     32.3
# 19   Canberra     15.6     33.4
# 20   Canberra     15.3     33.4
# 21   Canberra     16.4     19.4
# 22   Canberra     12.8     18.5
# 23   Canberra     12.0     24.3
# 24   Canberra     15.4     28.4
# 25   Canberra     15.6     26.9
# 26   Canberra     13.3     22.2
# 27   Canberra     12.9     28.0
# ...

# %%
l = ['RISK_MM','Location']

# %%
df[l]
# Out:
#      RISK_MM  Location
# 0        3.6  Canberra
# 1        3.6  Canberra
# 2       39.8  Canberra
# 3        2.8  Canberra
# 4        0.0  Canberra
# 5        0.2  Canberra
# 6        0.0  Canberra
# 7        0.0  Canberra
# 8       16.2  Canberra
# 9        0.0  Canberra
# 10       0.2  Canberra
# 11       0.0  Canberra
# 12       0.0  Canberra
# 13       0.0  Canberra
# 14       0.0  Canberra
# 15       0.0  Canberra
# 16       1.2  Canberra
# 17       0.6  Canberra
# 18       0.0  Canberra
# 19       0.0  Canberra
# 20       0.4  Canberra
# 21      25.8  Canberra
# 22       0.4  Canberra
# 23       0.0  Canberra
# 24       0.0  Canberra
# 25       0.2  Canberra
# 26       0.0  Canberra
# 27       0.0  Canberra
# 28       0.4  Canberra
# 29      22.6  Canberra
# ..       ...       ...
# 336      0.0  Canberra
# 337      7.6  Canberra
# 338      3.0  Canberra
# 339      0.0  Canberra
# 340      8.2  Canberra
# 341      0.0  Canberra
# 342      0.0  Canberra
# 343      0.0  Canberra
# ...

# %%
df[['Temp_diff']] = df['Temp3pm'] - df['Temp9am']

# %%
df.head()
# Out:
#         Date  Location  MinTemp  ...  RISK_MM  RainTomorrow  Temp_diff
# 0  11/1/2007  Canberra      8.0  ...      3.6           Yes        9.2
# 1  11/2/2007  Canberra     14.0  ...      3.6           Yes        8.2
# 2  11/3/2007  Canberra     13.7  ...     39.8           Yes        4.8
# 3  11/4/2007  Canberra     13.3  ...      2.8           Yes        0.6
# 4  11/5/2007  Canberra      7.6  ...      0.0            No        4.3
#
# [5 rows x 25 columns]

# %%
df.isnull().sum()
# Out:
# Date              0
# Location          0
# MinTemp           0
# MaxTemp           0
# Rainfall          0
# Evaporation       0
# Sunshine          3
# WindGustDir       3
# WindGustSpeed     2
# WindDir9am       31
# WindDir3pm        1
# WindSpeed9am      7
# WindSpeed3pm      0
# Humidity9am       0
# Humidity3pm       0
# Pressure9am       0
# Pressure3pm       0
# Cloud9am          0
# Cloud3pm          0
# Temp9am           0
# Temp3pm           0
# RainToday         0
# RISK_MM           0
# RainTomorrow      0
# Temp_diff         0
# dtype: int64

# %%
df[df['MinTemp'] > 10]
# Out:
#            Date  Location  MinTemp  ...  RISK_MM  RainTomorrow  Temp_diff
# 1     11/2/2007  Canberra     14.0  ...      3.6           Yes        8.2
# 2     11/3/2007  Canberra     13.7  ...     39.8           Yes        4.8
# 3     11/4/2007  Canberra     13.3  ...      2.8           Yes        0.6
# 12   11/13/2007  Canberra     10.1  ...      0.0            No       10.1
# 13   11/14/2007  Canberra     12.1  ...      0.0            No       11.0
# 14   11/15/2007  Canberra     10.1  ...      0.0            No       11.7
# 15   11/16/2007  Canberra     12.4  ...      0.0            No       11.6
# 16   11/17/2007  Canberra     13.8  ...      1.2           Yes        9.6
# 17   11/18/2007  Canberra     11.7  ...      0.6            No        8.5
# 18   11/19/2007  Canberra     12.4  ...      0.0            No       11.0
# 19   11/20/2007  Canberra     15.6  ...      0.0            No        9.2
# 20   11/21/2007  Canberra     15.3  ...      0.4            No       10.6
# ...

# %%
df.query('WindGustDir == "NW" and MinTemp > 10').describe()
# Out:
#          MinTemp    MaxTemp   Rainfall  ...    Temp3pm    RISK_MM  Temp_diff
# count  21.000000  21.000000  21.000000  ...  21.000000  21.000000  21.000000
# mean   13.195238  25.923810   3.866667  ...  24.414286   3.133333   6.966667
# std     2.139737   4.906211   9.146438  ...   5.193870   8.688690   3.908879
# min    10.100000  15.000000   0.000000  ...  13.700000   0.000000  -0.600000
# 25%    12.000000  23.800000   0.000000  ...  21.100000   0.000000   4.800000
# 50%    12.500000  26.500000   0.000000  ...  25.100000   0.000000   7.800000
# 75%    13.700000  29.400000   3.600000  ...  28.600000   2.800000  10.100000
# max    18.000000  34.900000  39.800000  ...  33.100000  39.800000  12.400000
#
# [8 rows x 18 columns]

# %%
df[(~df['WindGustDir'].isnull()) & (df['MinTemp'] <= 10)]
# Out:
#            Date  Location  MinTemp  ...  RISK_MM  RainTomorrow  Temp_diff
# 0     11/1/2007  Canberra      8.0  ...      3.6           Yes        9.2
# 4     11/5/2007  Canberra      7.6  ...      0.0            No        4.3
# 5     11/6/2007  Canberra      6.2  ...      0.2            No        3.9
# 6     11/7/2007  Canberra      6.1  ...      0.0            No        4.9
# 7     11/8/2007  Canberra      8.3  ...      0.0            No        3.4
# 8     11/9/2007  Canberra      8.8  ...     16.2           Yes        4.8
# 9    11/10/2007  Canberra      8.4  ...      0.0            No        8.4
# 10   11/11/2007  Canberra      9.1  ...      0.2            No        9.4
# 11   11/12/2007  Canberra      8.5  ...      0.0            No        9.2
# 42   12/13/2007  Canberra      9.6  ...      0.0            No        3.4
# 43   12/14/2007  Canberra      8.9  ...      0.0            No        9.2
# 47   12/18/2007  Canberra      7.5  ...      0.0            No        4.5
# ...

# %%
gby = df.groupby(by = 'WindGustDir')

# %%
gby.agg(['mean','sum'])
# Out:
#                MinTemp           MaxTemp  ... RISK_MM  Temp_diff
#                   mean    sum       mean  ...     sum       mean    sum
# WindGustDir                               ...
# E             9.981081  369.3  24.086486  ...    36.2   8.008108  296.3
# ENE          11.213333  336.4  23.333333  ...    14.2   6.790000  203.7
# ESE           9.169565  210.9  20.821739  ...    34.6   5.743478  132.1
# N             2.919048   61.3  18.538095  ...    16.0   8.180952  171.8
# NE           10.750000  172.0  25.893750  ...    20.0   8.262500  132.2
# NNE          10.275000   82.2  23.737500  ...     7.2   6.850000   54.8
# NNW           6.022727  265.0  20.459091  ...   106.2   7.545455  332.0
# NW            6.131507  447.6  19.478082  ...   130.0   6.576712  480.1
# S             5.131818  112.9  17.013636  ...    29.0   5.750000  126.5
# SE            7.183333   86.2  18.491667  ...     0.6   4.991667   59.9
# ...

# %%
match = pd.read_csv('https://github.com/Shreyas3108/Upgrad_DS/raw/master/matches.csv')

# %%
match.head()
# Out:
#    id  season       city  ...         umpire1        umpire2 umpire3
# 0   1    2017  Hyderabad  ...     AY Dandekar       NJ Llong     NaN
# 1   2    2017       Pune  ...  A Nand Kishore         S Ravi     NaN
# 2   3    2017     Rajkot  ...     Nitin Menon      CK Nandan     NaN
# 3   4    2017     Indore  ...    AK Chaudhary  C Shamshuddin     NaN
# 4   5    2017  Bangalore  ...             NaN            NaN     NaN
#
# [5 rows x 18 columns]

# %%
match.head()
# Out:
#    id  season       city  ...         umpire1        umpire2 umpire3
# 0   1    2017  Hyderabad  ...     AY Dandekar       NJ Llong     NaN
# 1   2    2017       Pune  ...  A Nand Kishore         S Ravi     NaN
# 2   3    2017     Rajkot  ...     Nitin Menon      CK Nandan     NaN
# 3   4    2017     Indore  ...    AK Chaudhary  C Shamshuddin     NaN
# 4   5    2017  Bangalore  ...             NaN            NaN     NaN
#
# [5 rows x 18 columns]

# %%
match2 = match.query('city == "Chennai"')

# %%
match2.pivot_table(index=['team1'] , columns=['team2'],values = ['winner'] , aggfunc = 'count')
# Out:
#                                          winner  ...
# team2                       Chennai Super Kings  ... Sunrisers Hyderabad
# team1                                            ...
# Chennai Super Kings                         NaN  ...                 1.0
# Deccan Chargers                             1.0  ...                 NaN
# Delhi Daredevils                            1.0  ...                 NaN
# Kings XI Punjab                             2.0  ...                 NaN
# Kolkata Knight Riders                       4.0  ...                 NaN
# Mumbai Indians                              2.0  ...                 NaN
# Pune Warriors                               1.0  ...                 NaN
# Rajasthan Royals                            4.0  ...                 NaN
# Royal Challengers Bangalore                 5.0  ...                 NaN
# Sunrisers Hyderabad                         2.0  ...                 NaN
#
# [10 rows x 12 columns]
